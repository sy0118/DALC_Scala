# %% [markdown]
# # Colab 실습 하기

# %% [markdown]
# ## 1. 마크다운으로 내 깃허브 링크 삽입하기
#
# (여기를 채워주세요! )

# %% [markdown]
# https://github.com/sy0118/DALC_Scala

# %% [markdown]
# ## 2. 마크다운으로 이미지 삽입하기
#
# - 이미지는 인터넷에 있는 이미지 아무거나 또는 내 pc에 저장되어 있는 아무이미지를 삽입해주시면 됩니다.
#
# (여기를 채워주세요!)![DitzPbSV4AIp3G3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 3. 마크다운으로 수업 배운 것 정리해보기
# - 전공수업, 교양 수업, 오늘 ot내용, 요즘 준비하는 자격증 내용 등등 기타 자기가 최근 배운 것 아무거나 최소 3줄이상 작성해주세요. (이때 단어강조하기, 문장 띄어쓰기, 인용구등 사용하기)
#
# (여기를 채워주세요!)

# %% [markdown]
# #### DALC 스칼라반 OT
# 코랩에서 이미지 삽입하는 방법을 이번 과제를 통해 처음 알게되었다.
# 컴퓨터프로그래밍입문을 복습하려고 하고있다.
# 코랩의 다양한 효과 (고양이효과) 등을 알게 되었다.
